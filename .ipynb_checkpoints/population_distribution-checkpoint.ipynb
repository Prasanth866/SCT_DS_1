# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.read_csv('population/popindia.csv')
a.drop([36],inplace=True)
a['Population(in Millions)']=a['Population[50]']/1000000

# %%
a.plot(kind='bar',x='State/UT',y='Population(in Millions)')
plt.show()
